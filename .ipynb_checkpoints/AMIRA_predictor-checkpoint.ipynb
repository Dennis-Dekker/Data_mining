# %%
import numpy as np
import pandas as pd
import statistics
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA 
from sklearn.metrics import mean_squared_error

# %%
#read file
df_data = pd.read_csv("data/dataset_mood_smartphone.csv")
df_data.head()
# Out:
#    Unnamed: 0       id                     time variable  value
# 0           1  AS14.01  2014-02-26 13:00:00.000     mood    6.0
# 1           2  AS14.01  2014-02-26 15:00:00.000     mood    6.0
# 2           3  AS14.01  2014-02-26 18:00:00.000     mood    6.0
# 3           4  AS14.01  2014-02-26 21:00:00.000     mood    7.0
# 4           5  AS14.01  2014-02-27 09:00:00.000     mood    6.0

# %%
prev_day="2014-02-26"
new_data=pd.DataFrame(columns=['id', 'time', 'var',"value"])
temp_list=[]
for index, row in df_data.iterrows():
    date=row["time"].split(" ")[0]
    if date != prev_day:
        new_data.loc[index]=[df_data.loc[index-1]["id"], prev_day , df_data.loc[index-1]["variable"], statistics.mean(temp_list)]
        temp_list=[row["value"]]
    else:
        temp_list.append(row["value"])
    prev_day=date

# %%
ids = list(np.unique(np.array(df_data["id"])))

# %%
for id in ids:
    df_mood_id = new_data.loc[(new_data['var'] == "mood") & (new_data['id']==id)]
    df_time_value = df_mood_id[['id','time',"value"]].reset_index()
    df_time_value['time'] = pd.to_datetime(df_time_value['time'],format="%Y-%m-%d")

    X = []

    prev_index = 0
    for i, row in df_time_value.iterrows():
        delta = (df_time_value['time'].iloc[prev_index] - df_time_value['time'].iloc[i]).days
        if delta < -1:
            for n in range(abs(delta)-1):
                X.append(None)
            X.append(df_time_value['value'].iloc[i])
        elif delta > 0:
            for n in range(365-delta-1):
                X.append(None)
            X.append(df_time_value['value'].iloc[i])
        else:
            X.append(df_time_value['value'].iloc[i])
        prev_index = i

    #Set up the input for ARIMA
    # index = df_time_value[["time"]].values
    # data_np = df_time_value["value"].values
    series = pd.Series(X)
    X= series.values
    print(X)
#     np.savetxt("dataset_arima.txt", X)
    X = [x for x in X if str(x) != 'nan']
    size = int(len(X) * 0.66)
    train, test = X[0:size], X[size:len(X)]

    history = [x for x in train]
    predictions = list()
    for t in range(len(test)):
        #order=(p,d,q) 
        model = ARIMA(history, order=(3,1,0))#tunne parameters!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        model_fit = model.fit(disp=0)
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)data:image/png;base64,...
#         print('predicted=%f, expected=%f' % (yhat, obs))
    error = mean_squared_error(test, predictions)
    plt.plot(test, predictions)
    plt.show()
    print('Test MSE: %.3f' % error)
# Out:
#   File "<ipython-input-34-386b415097a5>", line 44
#     history.append(obs)data:image/png;base64,...
#                           ^
# SyntaxError: invalid syntax

# %%
df_mood_id = new_data.loc[(new_data['var'] == "mood")]
df_time_value = df_mood_id[['id','time',"value"]].reset_index()
df_time_value['time'] = pd.to_datetime(df_time_value['time'],format="%Y-%m-%d")

X = []

id = 'AS14.01'
prev_index = 0
for i, row in df_time_value.iterrows():
    delta = (df_time_value['time'].iloc[prev_index] - df_time_value['time'].iloc[i]).days
    if delta < -1:
        for n in range(abs(delta)-1):
            X.append(None)
        X.append(df_time_value['value'].iloc[i])
    elif delta > 0:
        for n in range(365-delta-1):
            X.append(None)
        X.append(df_time_value['value'].iloc[i])
    else:
        X.append(df_time_value['value'].iloc[i])
    prev_index = i

#Set up the input for ARIMA
# index = df_time_value[["time"]].values
# data_np = df_time_value["value"].values
series = pd.Series(X)
X= series.values
X = [x for x in X if str(x) != 'nan']
# X = [x for x in X]
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]

history = [x for x in train]
predictions = list()
for t in range(len(test)):
    #order=(p,d,q) 
    model = ARIMA(history, order=(1,1,1))#tunne parameters!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# predicted=7.327354, expected=7.000000
# predicted=7.139577, expected=6.800000
# predicted=7.040528, expected=6.000000
# predicted=6.692318, expected=6.333333
# predicted=6.706455, expected=7.400000
# predicted=7.062173, expected=7.000000
# predicted=6.962265, expected=6.833333
# predicted=6.904209, expected=7.500000
# predicted=7.151157, expected=6.000000
# predicted=6.631105, expected=7.000000
# predicted=6.911271, expected=7.000000
# predicted=6.926274, expected=7.400000
# predicted=7.092064, expected=7.000000
# predicted=6.989369, expected=7.250000
# predicted=7.087075, expected=7.000000
# predicted=7.018392, expected=7.500000
# predicted=7.206924, expected=5.200000
# predicted=6.381227, expected=6.400000
# predicted=6.645581, expected=7.000000
# predicted=6.834572, expected=7.600000
# predicted=7.091578, expected=7.200000
# predicted=7.020361, expected=7.400000
# predicted=7.125310, expected=7.000000
# predicted=7.016782, expected=6.200000
# predicted=6.709586, expected=6.600000
# predicted=6.782520, expected=6.800000
# predicted=6.830535, expected=7.200000
# predicted=6.978680, expected=7.000000
# predicted=6.937284, expected=7.000000
# predicted=6.947416, expected=6.200000
# predicted=6.651200, expected=6.600000
# predicted=6.733597, expected=7.000000
# predicted=6.865612, expected=7.400000
# predicted=7.039674, expected=7.000000
# predicted=6.943086, expected=6.833333
# predicted=6.888677, expected=6.750000
# predicted=6.848695, expected=7.800000
# predicted=7.233821, expected=7.000000
# predicted=7.017219, expected=7.000000
# predicted=7.014995, expected=7.500000
# predicted=7.203499, expected=8.000000
# predicted=7.441515, expected=6.500000
# predicted=6.957774, expected=8.000000
# predicted=7.455540, expected=7.400000
# predicted=7.317037, expected=6.500000
# predicted=6.990070, expected=7.750000
# predicted=7.383755, expected=7.000000
# predicted=7.162037, expected=6.600000
# predicted=6.986694, expected=6.400000
# predicted=6.850685, expected=6.500000
# predicted=6.817631, expected=7.200000
# predicted=7.031767, expected=6.500000
# predicted=6.795093, expected=6.250000
# predicted=6.654227, expected=7.500000
# predicted=7.060785, expected=6.800000
# predicted=6.867589, expected=7.400000
# predicted=7.081787, expected=8.250000
# predicted=7.452299, expected=6.500000
# predicted=6.922120, expected=6.000000
# predicted=6.667819, expected=6.250000
# predicted=6.658923, expected=7.000000
# predicted=6.878702, expected=7.400000
# predicted=7.048540, expected=7.200000
# predicted=7.026886, expected=6.000000
# predicted=6.603138, expected=6.200000
# predicted=6.586830, expected=7.000000
# predicted=6.829892, expected=6.500000
# predicted=6.667498, expected=6.400000
# predicted=6.604565, expected=7.200000
# predicted=6.874527, expected=6.666667
# predicted=6.723611, expected=6.800000
# predicted=6.765172, expected=7.000000
# predicted=6.845609, expected=7.500000
# predicted=7.056786, expected=7.000000
# predicted=6.936071, expected=6.600000
# predicted=6.795843, expected=6.400000
# predicted=6.691550, expected=6.200000
# predicted=6.572906, expected=8.000000
# predicted=7.191811, expected=8.200000
# predicted=7.390930, expected=7.200000
# predicted=7.132031, expected=7.000000
# predicted=7.066611, expected=6.600000
# predicted=6.905203, expected=6.400000
# predicted=6.785014, expected=6.800000
# predicted=6.881589, expected=6.750000
# predicted=6.851322, expected=8.000000
# predicted=7.309528, expected=6.750000
# predicted=6.937084, expected=6.750000
# predicted=6.910525, expected=6.400000
# predicted=6.755938, expected=6.400000
# predicted=6.705260, expected=6.600000
# predicted=6.737419, expected=6.600000
# predicted=6.717923, expected=7.750000
# predicted=7.136239, expected=7.000000
# predicted=6.940144, expected=7.400000
# predicted=7.099724, expected=6.800000
# predicted=6.916434, expected=6.800000
# predicted=6.900283, expected=6.000000
# predicted=6.584599, expected=7.200000
# predicted=6.954406, expected=8.000000
# predicted=7.291611, expected=8.000000
# predicted=7.392458, expected=6.400000
# predicted=6.871299, expected=7.250000
# predicted=7.127538, expected=6.200000
# predicted=6.749945, expected=5.800000
# predicted=6.521604, expected=6.600000
# predicted=6.726033, expected=8.000000
# predicted=7.239710, expected=7.800000
# predicted=7.267771, expected=8.000000
# predicted=7.415899, expected=6.600000
# predicted=6.960133, expected=6.200000
# predicted=6.758866, expected=6.800000
# predicted=6.915567, expected=7.200000
# predicted=7.053236, expected=7.800000
# predicted=7.301332, expected=7.400000
# predicted=7.213642, expected=6.500000
# predicted=6.894664, expected=6.800000
# predicted=6.958705, expected=6.600000
# predicted=6.862431, expected=6.800000
# predicted=6.905496, expected=8.000000
# predicted=7.349910, expected=6.200000
# predicted=6.750311, expected=6.400000
# predicted=6.755089, expected=7.000000
# predicted=6.937109, expected=6.000000
# predicted=6.566915, expected=6.400000
# predicted=6.644751, expected=7.400000
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# predicted=6.992812, expected=7.400000
# predicted=7.046169, expected=7.200000
# predicted=7.015679, expected=7.400000
# predicted=7.115241, expected=7.600000
# predicted=7.227788, expected=7.000000
# predicted=7.047329, expected=6.600000
# predicted=6.889438, expected=6.200000
# predicted=6.700541, expected=7.600000
# predicted=7.169819, expected=8.000000
# predicted=7.377038, expected=7.200000
# predicted=7.150796, expected=5.800000
# predicted=6.623746, expected=5.400000
# predicted=6.364812, expected=7.400000
# predicted=7.015261, expected=6.400000
# predicted=6.680808, expected=7.400000
# predicted=7.026347, expected=7.000000
# predicted=6.920314, expected=7.400000
# predicted=7.081868, expected=7.000000
# predicted=6.969027, expected=7.600000
# predicted=7.200381, expected=7.600000
# predicted=7.249425, expected=7.000000
# predicted=7.064451, expected=7.400000
# predicted=7.209030, expected=5.800000
# predicted=6.625924, expected=7.000000
# predicted=6.981154, expected=8.750000
# predicted=7.643865, expected=7.600000
# predicted=7.343184, expected=7.200000
# predicted=7.223396, expected=7.800000
# predicted=7.448369, expected=7.600000
# predicted=7.416515, expected=8.600000
# predicted=7.819848, expected=7.500000
# predicted=7.501376, expected=7.200000
# predicted=7.387127, expected=6.800000
# predicted=7.211285, expected=7.800000
# predicted=7.540328, expected=8.000000
# predicted=7.648509, expected=7.600000
# predicted=7.541618, expected=7.600000
# predicted=7.549603, expected=9.333333
# predicted=8.211408, expected=8.000000
# predicted=7.851659, expected=7.800000
# predicted=7.795860, expected=7.200000
# predicted=7.568572, expected=6.600000
# predicted=7.292850, expected=7.600000
# predicted=7.588005, expected=7.200000
# predicted=7.439526, expected=6.400000
# predicted=7.108882, expected=7.400000
# predicted=7.401931, expected=7.666667
# predicted=7.503014, expected=7.800000
# predicted=7.573724, expected=7.000000
# predicted=7.299956, expected=6.400000
# predicted=7.037696, expected=6.600000
# predicted=7.036478, expected=7.000000
# predicted=7.135892, expected=7.800000
# predicted=7.424813, expected=6.800000
# predicted=7.090611, expected=7.500000
# predicted=7.320690, expected=7.000000
# predicted=7.153818, expected=6.500000
# predicted=6.946770, expected=7.500000
# predicted=7.270414, expected=6.800000
# predicted=7.034687, expected=8.000000
# predicted=7.457780, expected=5.750000
# predicted=6.684951, expected=7.600000
# predicted=7.254380, expected=7.200000
# predicted=7.150263, expected=8.000000
# predicted=7.451951, expected=7.800000
# predicted=7.446461, expected=7.000000
# predicted=7.195244, expected=7.000000
# predicted=7.171797, expected=7.400000
# predicted=7.298718, expected=7.800000
# predicted=7.459075, expected=7.200000
# predicted=7.280170, expected=6.800000
# predicted=7.123363, expected=6.800000
# predicted=7.084306, expected=6.200000
# predicted=6.827988, expected=7.800000
# predicted=7.342461, expected=5.800000
# predicted=6.666036, expected=6.750000
# predicted=6.905258, expected=7.800000
# predicted=7.270986, expected=8.000000
# predicted=7.411429, expected=7.250000
# predicted=7.208399, expected=7.000000
# predicted=7.122475, expected=8.000000
# predicted=7.473347, expected=7.000000
# predicted=7.172784, expected=8.000000
# predicted=7.516381, expected=7.250000
# predicted=7.303261, expected=7.500000
# predicted=7.388265, expected=7.000000
# predicted=7.220702, expected=6.200000
# predicted=6.902312, expected=6.400000
# predicted=6.890085, expected=6.800000
# predicted=6.977692, expected=7.400000
# predicted=7.176454, expected=6.800000
# predicted=6.984091, expected=7.000000
# predicted=7.035319, expected=6.333333
# predicted=6.787672, expected=6.500000
# predicted=6.793368, expected=8.500000
# predicted=7.489940, expected=7.250000
# predicted=7.154694, expected=8.000000
# predicted=7.439019, expected=8.200000
# predicted=7.580243, expected=7.750000
# predicted=7.490513, expected=7.200000
# predicted=7.320395, expected=7.800000
# predicted=7.526720, expected=7.600000
# predicted=7.487204, expected=8.600000
# predicted=7.868623, expected=7.200000
# predicted=7.446574, expected=8.250000
# predicted=7.801452, expected=8.200000
# predicted=7.841032, expected=8.000000
# predicted=7.814717, expected=8.250000
# predicted=7.931579, expected=7.800000
# predicted=7.808718, expected=7.600000
# predicted=7.734894, expected=8.000000
# predicted=7.864903, expected=7.000000
# predicted=7.518017, expected=7.500000
# predicted=7.635866, expected=7.200000
# predicted=7.510783, expected=6.400000
# predicted=7.181358, expected=7.600000
# predicted=7.523057, expected=7.800000
# predicted=7.605991, expected=7.500000
# predicted=7.521401, expected=6.000000
# predicted=6.974816, expected=6.500000
# predicted=7.035565, expected=7.000000
# predicted=7.152230, expected=7.600000
# predicted=7.354729, expected=7.800000
# predicted=7.459860, expected=7.600000
# predicted=7.428603, expected=8.000000
# predicted=7.596495, expected=8.000000
# predicted=7.645610, expected=7.333333
# predicted=7.444215, expected=7.800000
# predicted=7.602494, expected=7.800000
# predicted=7.626783, expected=7.400000
# predicted=7.501679, expected=7.000000
# predicted=7.343523, expected=7.000000
# predicted=7.303153, expected=7.600000
# predicted=7.487740, expected=8.200000
# predicted=7.721761, expected=7.600000
# predicted=7.558878, expected=6.000000
# predicted=6.977821, expected=7.000000
# predicted=7.230191, expected=7.800000
# predicted=7.497130, expected=7.600000
# predicted=7.459893, expected=7.800000
# predicted=7.550153, expected=7.800000
# predicted=7.579850, expected=8.000000
# predicted=7.679492, expected=6.800000
# predicted=7.277577, expected=7.750000
# predicted=7.570382, expected=7.800000
# predicted=7.610206, expected=8.400000
# predicted=7.852591, expected=7.600000
# predicted=7.624418, expected=7.600000
# predicted=7.622263, expected=7.800000
# predicted=7.693594, expected=7.600000
# predicted=7.633608, expected=8.000000
# predicted=7.776728, expected=7.800000
# predicted=7.730580, expected=8.000000
# predicted=7.812727, expected=8.000000
# predicted=7.835672, expected=7.600000
# predicted=7.709432, expected=7.800000
# predicted=7.770528, expected=7.750000
# predicted=7.756514, expected=8.200000
# predicted=7.921064, expected=7.666667
# predicted=7.759959, expected=7.800000
# predicted=7.798484, expected=7.200000
# predicted=7.580229, expected=7.750000
# predicted=7.737209, expected=7.600000
# predicted=7.684787, expected=8.400000
# predicted=7.967178, expected=7.600000
# predicted=7.727390, expected=7.400000
# predicted=7.640322, expected=7.800000
# predicted=7.758562, expected=7.750000
# predicted=7.746004, expected=7.800000
# predicted=7.765450, expected=8.000000
# predicted=7.843078, expected=7.600000
# predicted=7.716723, expected=8.200000
# predicted=7.922044, expected=7.500000
# predicted=7.701115, expected=7.800000
# predicted=7.787268, expected=7.800000
# predicted=7.789569, expected=8.000000
# predicted=7.864232, expected=8.000000
# predicted=7.881028, expected=7.800000
# predicted=7.823204, expected=8.200000
# predicted=7.966612, expected=8.000000
# predicted=7.922345, expected=7.800000
# predicted=7.859692, expected=7.800000
# predicted=7.853513, expected=8.000000
# predicted=7.920727, expected=6.666667
# predicted=7.446894, expected=6.600000
# predicted=7.329856, expected=6.800000
# predicted=7.317449, expected=7.400000
# predicted=7.477809, expected=6.600000
# predicted=7.173300, expected=6.600000
# predicted=7.102824, expected=7.000000
# predicted=7.189028, expected=7.000000
# predicted=7.165348, expected=7.200000
# predicted=7.219401, expected=7.800000
# predicted=7.441338, expected=7.000000
# predicted=7.189166, expected=6.800000
# predicted=7.092622, expected=6.200000
# predicted=6.834891, expected=7.000000
# predicted=7.051560, expected=6.750000
# predicted=6.952424, expected=7.000000
# predicted=7.019636, expected=6.800000
# predicted=6.943346, expected=7.800000
# predicted=7.295340, expected=8.000000
# predicted=7.433307, expected=6.400000
# predicted=6.914312, expected=7.000000
# predicted=7.071715, expected=7.000000
# predicted=7.063307, expected=6.500000
# predicted=6.872776, expected=7.000000
# predicted=7.010508, expected=7.000000
# predicted=7.009506, expected=7.400000
# predicted=7.155256, expected=6.800000
# predicted=6.965835, expected=7.000000
# predicted=7.018982, expected=7.000000
# predicted=7.016959, expected=7.000000
# predicted=7.015181, expected=7.000000
# predicted=7.013619, expected=7.400000
# predicted=7.158451, expected=7.200000
# predicted=7.115117, expected=7.000000
# predicted=7.052712, expected=6.750000
# predicted=6.955278, expected=7.000000
# predicted=7.021943, expected=7.000000
# predicted=7.019568, expected=7.333333
# predicted=7.139281, expected=7.000000
# predicted=7.041419, expected=7.000000
# predicted=7.036695, expected=7.000000
# predicted=7.032541, expected=7.000000
# predicted=7.028888, expected=7.000000
# predicted=7.025676, expected=8.000000
# predicted=7.388062, expected=7.000000
# predicted=7.097795, expected=8.000000
# predicted=7.450578, expected=8.000000
# predicted=7.519163, expected=8.400000
# predicted=7.727158, expected=7.600000
# predicted=7.517745, expected=7.000000
# predicted=7.306446, expected=7.800000
# predicted=7.563702, expected=7.333333
# predicted=7.422529, expected=8.250000
# predicted=7.748069, expected=7.666667
# predicted=7.598504, expected=8.600000
# predicted=7.950380, expected=8.000000
# predicted=7.815176, expected=7.500000
# predicted=7.655726, expected=8.000000
# predicted=7.820219, expected=8.500000
# predicted=8.027801, expected=8.500000
# predicted=8.091158, expected=7.000000
# predicted=7.593897, expected=7.000000
# predicted=7.516131, expected=7.000000
# predicted=7.451295, expected=8.000000
# predicted=7.761984, expected=8.000000
# predicted=7.792293, expected=7.000000
# predicted=7.453584, expected=7.500000
# predicted=7.580533, expected=8.000000
# predicted=7.753653, expected=7.000000
# predicted=7.420476, expected=7.000000
# predicted=7.368583, expected=7.250000
# predicted=7.414562, expected=7.500000
# predicted=7.485995, expected=8.666667
# predicted=7.915303, expected=7.000000
# predicted=7.401179, expected=6.000000
# predicted=6.986526, expected=6.000000
# predicted=6.861479, expected=7.750000
# predicted=7.400658, expected=7.250000
# predicted=7.260206, expected=7.200000
# predicted=7.240980, expected=7.200000
# predicted=7.236315, expected=7.000000
# predicted=7.158862, expected=7.200000
# predicted=7.212865, expected=7.400000
# predicted=7.285016, expected=7.666667
# predicted=7.397415, expected=7.400000
# predicted=7.333215, expected=7.200000
# predicted=7.268694, expected=6.200000
# predicted=6.894999, expected=5.200000
# predicted=6.437522, expected=7.000000
# predicted=6.951678, expected=8.400000
# predicted=7.481454, expected=7.600000
# predicted=7.295501, expected=6.200000
# predicted=6.816223, expected=6.750000
# predicted=6.945648, expected=6.200000
# predicted=6.719579, expected=6.400000
# predicted=6.730732, expected=7.000000
# predicted=6.913035, expected=8.333333
# predicted=7.419812, expected=7.250000
# predicted=7.125955, expected=5.000000
# predicted=6.313362, expected=6.600000
# predicted=6.748008, expected=4.800000
# predicted=6.066238, expected=7.600000
# predicted=6.939190, expected=6.000000
# predicted=6.436458, expected=6.000000
# predicted=6.381648, expected=5.000000
# predicted=5.968620, expected=6.833333
# predicted=6.510699, expected=6.000000
# predicted=6.248939, expected=7.000000
# predicted=6.578288, expected=6.000000
# predicted=6.271743, expected=6.000000
# predicted=6.236902, expected=6.200000
# predicted=6.278088, expected=6.250000
# predicted=6.285841, expected=6.000000
# predicted=6.191543, expected=5.750000
# predicted=6.077239, expected=5.833333
# predicted=6.064560, expected=6.400000
# predicted=6.237622, expected=6.250000
# predicted=6.204571, expected=5.400000
# predicted=5.906429, expected=6.200000
# predicted=6.126464, expected=8.200000
# predicted=6.853040, expected=7.000000
# predicted=6.592346, expected=6.800000
# predicted=6.571420, expected=7.000000
# Test MSE: 0.391

# %%
df_time_value.shape
# Out:
# (1268, 4)
