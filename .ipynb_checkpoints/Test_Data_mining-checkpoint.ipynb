# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics

# %%
#read file
data=pd.read_csv("../Data_mining/data/dataset_mood_smartphone.csv")
data
# Out:
#         Unnamed: 0       id                     time        variable    value
# 0                1  AS14.01  2014-02-26 13:00:00.000            mood    6.000
# 1                2  AS14.01  2014-02-26 15:00:00.000            mood    6.000
# 2                3  AS14.01  2014-02-26 18:00:00.000            mood    6.000
# 3                4  AS14.01  2014-02-26 21:00:00.000            mood    7.000
# 4                5  AS14.01  2014-02-27 09:00:00.000            mood    6.000
# 5                6  AS14.01  2014-02-27 12:00:00.000            mood    6.000
# 6                7  AS14.01  2014-02-27 15:00:00.000            mood    7.000
# 7                8  AS14.01  2014-03-21 09:00:00.000            mood    6.000
# 8                9  AS14.01  2014-03-21 11:00:00.000            mood    6.000
# 9               10  AS14.01  2014-03-21 15:00:00.000            mood    7.000
# 10              11  AS14.01  2014-03-21 19:00:00.000            mood    6.000
# ...

# %%
# as14= data.loc[(data["variable"]=="mood") & (data["id"]=="AS14.01")]
# as14= as14.values
# plt.plot(as14[:, 2], as14[:, 4])
# plt.show()

# %%
# as14_m= data.loc[(data["variable"]=="mood") & (data["id"]=="AS14.01")]
# as14_e= data.loc[(data["variable"]=="circumplex.arousal") & (data["id"]=="AS14.01")]
# as14_m= as14_m.values
# as14_e = as14_e.values
# plt.plot(as14_m[:, 4], as14_e[:-1, 4])
#plt.show()

# %% [markdown]
# ### Preprocessing

# %%
#dict_variable is a dictionary with key the tuple (Id,variable) and value a dictionary with key the date and value a list 
#of values of the user for that day
dict_variable={}
previous_day="-"
for index, row in data.iterrows():
    #check if the row is the first one
    if index==0:
        dict_variable[(row["id"])]={}
        previous_day=row["time"].split(" ")[0].split("-")[1:]
        dict_variable[(row["id"])][("-".join(previous_day),row["variable"])]=list()
        dict_variable[(row["id"])][("-".join(previous_day),row["variable"])].append(row["value"])
    else:
        #check if you are still in the same day (different hour)
        current_day=row["time"].split(" ")[0].split("-")[1:]
        #print(current_day)
        if current_day!=previous_day or data.iloc[index-1,1]!=row["id"]:
            #you are in a new day
            if (row["id"]) not in dict_variable: dict_variable.update({(row["id"]):{}})
            dict_variable[(row["id"])][("-".join(current_day),row["variable"])]=list()
            dict_variable[(row["id"])][("-".join(current_day),row["variable"])].append(row["value"])
            #update the previous day
            previous_day=current_day
        elif current_day==previous_day:
            #you are in the same day
            if (row["id"]) not in dict_variable: dict_variable.update({(row["id"]):{}})
            dict_variable[(row["id"])][("-".join(current_day),row["variable"])].append(row["value"])
            previous_day=current_day

# %%
dict_variable[('AS14.02')]
# Out:
# {('03-16', 'mood'): [7.0, 6.0, 6.0],
#  ('03-17', 'mood'): [7.0, 8.0, 5.0, 7.0],
#  ('03-18', 'mood'): [8.0, 8.0, 8.0, 9.0, 8.0],
#  ('03-19', 'mood'): [8.0, 7.0, 6.0, 8.0, 5.0],
#  ('03-20', 'mood'): [7.0, 7.0, 7.0, 8.0],
#  ('03-21', 'mood'): [8.0, 6.0, 8.0, 8.0],
#  ('03-22', 'mood'): [8.0, 6.0, 6.0, 6.0],
#  ('03-23', 'mood'): [7.0, 6.0, 6.0, 6.0],
#  ('03-24', 'mood'): [6.0, 7.0, 6.0, 5.0, 8.0],
#  ('03-25', 'mood'): [8.0, 8.0, 8.0, 7.0],
#  ('03-26', 'mood'): [8.0, 6.0, 6.0, 7.0, 9.0],
#  ('03-27', 'mood'): [6.0, 7.0, 8.0, 8.0],
#  ('03-28', 'mood'): [7.0, 8.0, 5.0, 8.0, 6.0],
#  ('03-29', 'mood'): [7.0, 6.0, 9.0, 7.0],
#  ('03-30', 'mood'): [8.0, 7.0, 5.0, 8.0],
#  ('03-31', 'mood'): [6.0, 8.0, 6.0, 8.0, 8.0],
#  ('04-01', 'mood'): [8.0, 7.0, 8.0, 7.0, 7.0],
#  ('04-02', 'mood'): [6.0, 8.0, 8.0, 5.0, 5.0],
#  ('04-03', 'mood'): [6.0, 4.0, 7.0, 6.0],
#  ('04-04', 'mood'): [7.0, 8.0, 5.0, 4.0, 8.0],
#  ('04-05', 'mood'): [6.0, 8.0, 9.0, 8.0, 6.0],
# ...

# %%
variables_list=["mood","circumplex.arousal","circumplex.valence","activity","screen","call","sms","appCat.builtin","appCat.communication","appCat.entertainment","appCat.finance","appCat.game","appCat.office","appCat.other","appCat.social","appCat.other","appCat.travel","appCat.unknown","appCat.utilities","appCat.weather"]
#the days in the same month are considered as "Period"
#new_dict to store the preprocessed data. its format is: key is tuple of ID and period, value is a dictionary with key the attributes
#and value the value for that period. A period: days in same  month. target (value to predict): last day in the month
new_dict={}
current_month="-"
temp_list=[]
final_month_dates = {"01":"31", }

#Check if all the day are consecutive, otherwise remove some data if possible
for i in dict_variable:
    #i=id, var=variable, key=day
    previous_date = ""
    for key, var in dict_variable[i]:
        if var == "mood":
            if previous_date == "":
                previous_date = key
            elif previous_date.split("-")[0] == key.split("-")[0]:
                if previous_date.split("-")[1]
                #not fully implemented
                
            
            
    








for i in dict_variable:
    #i=id, var=variable, key=day
    previous_month="-"
    for key, var in dict_variable[(i)]:
        #calculate the mean values of each variable for each day
        mean=statistics.mean(dict_variable[(i)][(key, var)])
        #determine the actual month
        current_month=key.split("-")[0]
        print(i,var,key, mean)
        #if new month iteration:
        if previous_month!=current_month:
            #if you are in a new id,var combination
            if previous_month == "-":
                new_dict[(i, current_month)]={}
                print(new_dict)
            else:
                #remove the last element of the list (is the target)
                target=temp_list[-1]
                temp_list.remove(temp_list[-1])
                #add to the dictionary the target mood
                print(target)
                new_dict[(i, current_month)]={}
                new_dict[(i, current_month)]["target"]=target
                #add the mean of the values for the days in the month (expect the last one) to the dictionary
                new_dict[(i, current_month)][var]=statistics.mean(temp_list)
                #reset the target list for the new month
                temp_list=[]
            #append the first mean for the new date
            temp_list.append(mean)
            #update the previous_month
            previous_month=current_month
        elif current_month == previous_month:
            temp_list.append(mean)

            
            
    #this is only to test with the first element of the dictionary       
    if i != "AS14.01":
        break
# Out:
#   File "<ipython-input-11-14bfad98e4e1>", line 13
#     if var ==
#               ^
# SyntaxError: invalid syntax

# %%
a={}
a["d"]={}
a["d"]["a"]=3
a
a["d"]["b"]=2

# %%
a=[1,2,3,4]
a[-1]
a.remove(a[-1])
a
